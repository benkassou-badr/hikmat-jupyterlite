# %% [markdown]
# <div style="width:100%;box-sizing:border-box;padding:22px 26px;border-radius:16px;background-color:#EAF3F4;background-image:linear-gradient(to right,#D5E5E7 0%,#EAF3F4 50%,#F7FBFB 100%);border:1px solid #BCD3D6;font-family:Arial,Helvetica,sans-serif;box-shadow:0 4px 14px rgba(36,75,80,.10);display:flex;align-items:center;justify-content:space-between;gap:28px;"><span style="display:inline-block;flex:1;min-width:0;text-align:left;"><span style="font-size:14px;letter-spacing:1.5px;text-transform:uppercase;color:#516477;font-weight:600;">Première — Spécialité Mathématiques</span><br><span style="display:inline-block;font-size:31px;font-weight:700;margin-top:7px;color:#082f73;">TP 1 — Suites numériques</span><br><span style="display:inline-block;font-size:17px;margin-top:8px;color:#445a70;">Découvrir, modéliser et expérimenter avec Python</span><br><span style="display:inline-block;width:100%;margin-top:18px;padding-top:11px;border-top:2px solid #d92d3a;font-size:13px;color:#29465f;">© <a href="https://hikmat.ma" target="_blank" rel="noopener noreferrer" style="color:inherit;text-decoration:none;"><strong>Hikmat.ma</strong></a> — Pr. Badr BENKASSOU</span></span><span style="display:inline-block;flex:0 0 auto;text-align:right;"><a href="https://hikmat.ma" target="_blank" rel="noopener noreferrer" style="display:inline-block;text-decoration:none;"><img src="data:image/png;base64,..." alt="Logo Hikmat.ma" style="display:block;width:330px;max-width:36vw;height:auto;background:transparent;border:0;"></a></span></div>

# %% [markdown]
# ### Informations élève
#
# **Nom et prénom :** ........................................................................
# **Classe :** .............................................  **Date :** .............................................
#
# > **Consigne générale.** Compléter les réponses et les cellules Python au fur et à mesure.
# > Les cellules contenant `...` sont volontairement incomplètes.

# %% [markdown]
# ## Exercice 1 : Découvrir les suites avec Python

# %% [markdown]
# **1. Suite explicite :**
#
# On considère la suite $(u_n)$ définie par :
#
# $$
# u_n=2n^2-3n+1.
# $$
#
# **a)** Calculer $u_0$ et $u_{10}$.
#
# **Réponse :**
#
# - $u_0=$
# - $u_{10}=$

# %% [markdown]
# **b)** Compléter le programme ci-dessous afin que la fonction `suite_exp(n)` renvoie le terme $u_n$.

# %%
def suite_exp(n):
    u = ...
    return ...

# %% [markdown]
# **c)** Déterminer avec Python $u_{10}$.

# %%
# À exécuter après avoir complété la fonction.
suite_exp(10)

# %% [markdown]
# **2. Suite définie par récurrence**
#
# On considère la suite $(v_n)$ définie par :
#
# $$
# v_0=2
# \qquad\text{et}\qquad
# v_{n+1}=v_n+3.
# $$
#
# **a)** Calculer $v_1$ et $v_{10}$.
#
# **Réponse :**
#
# - $v_1=$
# - $v_{10}=$

# %% [markdown]
# **b)** Compléter le programme ci-dessous afin que la fonction `suite_rec(n)` calcule successivement les termes à partir de $v_0$ et renvoie $v_n$.

# %%
def suite_rec(n):
    v = ...
    for k in range(...):
        v = ...
    return ...

# %% [markdown]
# **c)** Déterminer avec Python $v_{10}$.

# %%
# À exécuter après avoir complété la fonction.
suite_rec(10)

# %% [markdown]
# **3. Suite géométrique et limite**
#
# On dispose de la fonction ci-dessous permettant de calculer, à partir du terme $w_p$, le terme $w_n$ d'une suite géométrique de raison $q$.
#
# **a)** Compléter le programme ci-dessous.

# %%
def suite_geo(p, wp, q, n):
    w = ...
    for k in range(..., ...):
        w = ...
    return ...

# %% [markdown]
# **b)** Pour $w_0=2$ et $q=0{,}5$, calculer avec Python $w_{10}$, $w_{50}$ et $w_{100}$.

# %%
# À exécuter après avoir complété la fonction.
print("w_10  =", suite_geo(0, 2, 0.5, 10))
print("w_50  =", suite_geo(0, 2, 0.5, 50))
print("w_100 =", suite_geo(0, 2, 0.5, 100))

# %% [markdown]
# **c)** Compléter le tableau ci-dessous puis conjecturer le comportement de la suite selon la valeur de $q$.
#
# | $w_0 \backslash q$ | $-2$ | $-1$ | $-0{,}5$ | $0$ | $0{,}5$ | $1$ | $2$ |
# |---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | $2$  |  |  |  |  |  |  |  |
# | $-2$ |  |  |  |  |  |  |  |
#
# **Conjecture :**
#
# ............................................................................................................................
#
# ............................................................................................................................

# %% [markdown]
# ## Exercice 2 : Du tableur à Python
#
# On souhaite calculer les termes d’une suite à l’aide d’un tableur.

# %% [markdown]
# **1.** Pour chacune des feuilles de calcul, écrire la relation de récurrence vérifiée par la suite $(u_n)$.
#
# **a)**
#
# |   | A | B |
# |:--:|:--:|:--:|
# | **1** | $n$ | $u_n$ |
# | **2** | $1$ | $2$ |
# | **3** | $2$ | `=2*B2-1` |
# | **4** | $3$ |  |
#
# **Relation de récurrence :**
#
# ............................................................................................................................

# %% [markdown]
# **b)**
#
# |   | A | B |
# |:--:|:--:|:--:|
# | **1** | $n$ | $u_n$ |
# | **2** | $0$ | $-2$ |
# | **3** | $1$ | `=2*B2+3*A3` |
# | **4** | $2$ |  |
#
# **Relation de récurrence :**
#
# ............................................................................................................................

# %% [markdown]
# **2.** Pour chacune des deux suites précédentes, écrire une fonction Python permettant de calculer et de renvoyer le terme $u_n$ pour un rang $n$ donné.

# %%
# Fonction correspondant à la feuille a)
def suite_a(n):
    # À compléter
    ...

# %%
# Fonction correspondant à la feuille b)
def suite_b(n):
    # À compléter
    ...

# %% [markdown]
# ## Exercice 3 : Somme de termes
#
# On considère l'algorithme suivant.
#
# ```text
# S ← 0
# Pour k allant de 0 à 7 :
#     S ← S + 3 × 2^k
# Afficher S
# ```

# %% [markdown]
# **1.** Expliquer, avec une phrase, ce que permet de calculer cet algorithme.
#
# **Réponse :**
#
# ............................................................................................................................

# %% [markdown]
# **2.** Traduire cet algorithme en langage Python.

# %%
# À compléter

# %% [markdown]
# **3.** Déterminer la valeur de $S$ affichée par l'algorithme.
#
# **Réponse :** $S=$

# %% [markdown]
# ## Exercice 4 : Révisions avant un examen
#
# Un élève prépare un examen. On note $M_n$ la proportion du programme qu'il maîtrise au bout de $n$ jours de révision. Au départ, $M_0=0{,}2$.
#
# Chaque jour, il conserve $92\,\%$ de ce qu'il maîtrisait déjà et apprend $20\,\%$ de ce qu'il ne maîtrisait pas encore.

# %% [markdown]
# **1.** Expliquer pourquoi
#
# $$
# M_{n+1}=0{,}92M_n+0{,}20(1-M_n).
# $$
#
# **Réponse :**
#
# ............................................................................................................................

# %% [markdown]
# **2.** Montrer que
#
# $$
# M_{n+1}=0{,}72M_n+0{,}20.
# $$
#
# **Démonstration :**
#
# ............................................................................................................................

# %% [markdown]
# **3.** Calculer $M_1$, $M_2$ et $M_3$. Arrondir au millième si nécessaire.
#
# - $M_1=$
# - $M_2=$
# - $M_3=$

# %% [markdown]
# **4.** Compléter la fonction Python ci-dessous afin qu'elle renvoie la proportion du programme maîtrisée après $n$ jours.

# %%
def maitrise(n):
    M = ...
    for i in range(...):
        M = ...
    return M

# %% [markdown]
# **5.** On pose $R_n=M_n-\dfrac57$. Montrer que $(R_n)$ est une suite géométrique.
#
# **Démonstration :**
#
# ............................................................................................................................
#
# ............................................................................................................................

# %% [markdown]
# **6.** Exprimer $M_n$ en fonction de $n$, puis déterminer la limite de la suite $(M_n)$.
#
# **Expression de $M_n$ :**
#
# $$
# M_n=\qquad\qquad
# $$
#
# **Limite :**
#
# $$
# \lim_{n\to+\infty}M_n=\qquad\qquad
# $$

# %% [markdown]
# **7.** Compléter la fonction `objectif` ci-dessous afin qu'elle renvoie le premier jour où l'élève maîtrise strictement plus de $70\,\%$ du programme.

# %%
def objectif():
    n = 0
    M = ...
    while False:  # À remplacer par la condition correcte : M ... 0.70
        M = ...
        n = n + 1
    return n

# %% [markdown]
# **8.** Quelle valeur obtient-on ?

# %%
# À exécuter après avoir complété objectif().
objectif()

# %% [markdown]
# **Réponse :** ..............................................................................................................

# %% [markdown]
# ## Exercice 5 : Fibonacci et le nombre d'or
#
# La suite de Fibonacci est définie par :
#
# $$
# F_0=0,\qquad F_1=1,\qquad F_{n+2}=F_{n+1}+F_n.
# $$
#
# On souhaite observer numériquement le comportement des quotients $\dfrac{F_{n+1}}{F_n}$ lorsque $n$ devient grand.

# %% [markdown]
# **1.** Calculer $F_2$, $F_3$, $F_4$, $F_5$ et $F_6$.
#
# - $F_2=$
# - $F_3=$
# - $F_4=$
# - $F_5=$
# - $F_6=$

# %% [markdown]
# **2.** Compléter la fonction Python ci-dessous afin qu'elle construise et renvoie la liste des termes $F_0,F_1,\ldots,F_N$.

# %%
def fibonacci(N):
    termes = [..., ...]
    for k in range(...):
        termes.append(...)
    return termes

# %% [markdown]
# **3.** Écrire un programme qui affiche les quotients $\dfrac{F_{n+1}}{F_n}$ pour $1\leq n\leq 15$.

# %%
# À compléter

# %% [markdown]
# **4.** Conjecturer la limite de ces quotients.
#
# **Conjecture :**
#
# ............................................................................................................................

# %% [markdown]
# **5.** Comparer la conjecture avec le nombre $\varphi=\dfrac{1+\sqrt{5}}{2}$.

# %%
from math import sqrt

# À compléter si nécessaire.

# %% [markdown]
# **6.** Montrer que $\varphi$ vérifie $\varphi^2=\varphi+1$.
#
# **Démonstration :**
#
# ............................................................................................................................

# %% [markdown]
# **7.** Expliquer le lien entre cette relation et la récurrence de Fibonacci.
#
# **Réponse :**
#
# ............................................................................................................................
#
# ............................................................................................................................

# %% [markdown]
# <hr style="margin-top:28px;border:0;border-top:1px solid #b8c5cf;">
#
# <div style="text-align:center;font-family:Arial,Helvetica,sans-serif;font-size:12px;color:#52606d;padding:8px 0 2px;">
#   © <a href="https://hikmat.ma" target="_blank" rel="noopener noreferrer" style="color:inherit;text-decoration:none;"><strong>Hikmat.ma</strong></a> — Pr. Badr BENKASSOU
# </div>
